# %% [markdown]
# ## Deploy a pretrained/Fine-tuned hateBERT model in AWS Sagemaker with BentoML
#
# BentoML is a flexible and lightweight framework for creating, deploying, and managing machine learning services. We start out to use BentoML for the NLP model (pretrained BERT model for violence detection in message) deployment on cloud service. This notebook demostrates end-to-end project of deploying "GroNLP/hateBERT" model to AWS sagemaker using serverless architecture

# %% [markdown]
# ###

# %% [markdown]
# ### Deploy a pretrained model
# Service is the core component of BentoML, where the serving logic is defined. Using pretrained models from the Hugging Face does not require saving the model first in the BentoML model store. A custom runner can be implemented to download and run pretrained models at runtime.

# %%
# %%writefile service.py
import bentoml

from bentoml.io import Text, JSON
from transformers import pipeline

class PretrainedModelRunnable(bentoml.Runnable):
    SUPPORTED_RESOURCES = ("cpu",)
    SUPPORTS_CPU_MULTI_THREADING = True

    def __init__(self):
        self.classifier = pipeline(task="text-classification", model='GroNLP/hateBERT')

    @bentoml.Runnable.method(batchable=False)
    def __call__(self, input_text):
        return self.classifier(input_text)

runner = bentoml.Runner(PretrainedModelRunnable, name="pretrained_classifier")

svc = bentoml.Service('pretrained_classification_service', runners=[runner])

@svc.api(input=Text(), output=JSON())
async def detectViolence(input_series: str) -> list:
    return await runner.async_run(input_series)
# Out:
# Overwriting service.py

# %% [markdown]
# We can now run the BentoML server for our new service in development mode

# %%
# !bentoml serve service.py:svc --reload
# Out:
# 2023-03-30T11:37:37-0600 [INFO] [cli] Prometheus metrics for HTTP BentoServer from "service.py:svc" can be accessed at http://localhost:3000/metrics.
# 2023-03-30T11:37:38-0600 [INFO] [cli] Starting development HTTP BentoServer from "service.py:svc" listening on http://0.0.0.0:3000 (Press CTRL+C to quit)
# 2023-03-30 11:37:39 circus[23370] [INFO] Loading the plugin...
# 2023-03-30 11:37:39 circus[23370] [INFO] Endpoint: 'tcp://127.0.0.1:53824'
# 2023-03-30 11:37:39 circus[23370] [INFO] Pub/sub: 'tcp://127.0.0.1:53825'
# 2023-03-30T11:37:39-0600 [INFO] [observer] Watching directories: ['/Users/li/OMSA/FullStackDL/BentoML/huggingface_deployment', '/Users/li/bentoml/models']
# Some weights of the model checkpoint at GroNLP/hateBERT were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at GroNLP/hateBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ^C

# %% [markdown]
# ## Building a Bento
# Once the service definition is finalized, we can build the model and service into a `bento`
# . Bento is the distribution format for a service. It is a self-contained archive that contains all the source code, model files and dependency specifications required to run the service.
#
# To build a Bento, first create a `bentofile.yaml` file in your project directory

# %%
# %%writefile bentofile.yaml
# service: "service.py:svc"
# labels:
# include:
# - "*.py"
# python:
#   packages:
#   - transformers
#   - torch
# Out:
# Overwriting bentofile.yaml

# %%
# !bentoml build
# Out:
# Building BentoML service "pretrained_classification_service:rnm6k6gpfots36wa" from build context "/Users/li/OMSA/FullStackDL/BentoML/huggingface_deployment".
# Locking PyPI package versions.
# /Users/li/conda/miniconda3/envs/zenml/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
#
# ██████╗░███████╗███╗░░██╗████████╗░█████╗░███╗░░░███╗██╗░░░░░
# ██╔══██╗██╔════╝████╗░██║╚══██╔══╝██╔══██╗████╗░████║██║░░░░░
# ██████╦╝█████╗░░██╔██╗██║░░░██║░░░██║░░██║██╔████╔██║██║░░░░░
# ██╔══██╗██╔══╝░░██║╚████║░░░██║░░░██║░░██║██║╚██╔╝██║██║░░░░░
# ██████╦╝███████╗██║░╚███║░░░██║░░░╚█████╔╝██║░╚═╝░██║███████╗
# ╚═════╝░╚══════╝╚═╝░░╚══╝░░░╚═╝░░░░╚════╝░╚═╝░░░░░╚═╝╚══════╝
#
# Successfully built Bento(tag="pretrained_classification_service:rnm6k6gpfots36wa").
#
# Possible next steps:
#
#  * Containerize your Bento with `bentoml containerize`:
#     $ bentoml containerize pretrained_classification_service:rnm6k6gpfots36wa
#
#  * Push to BentoCloud with `bentoml push`:
#     $ bentoml push pretrained_classification_service:rnm6k6gpfots36wa

# %% [markdown]
# We can now run the BentoML server for our new service in development mode.

# %%
# !bentoml serve pretrained_classification_service:latest --production
# Out:
# 2023-03-30T12:56:29-0600 [INFO] [cli] Environ for worker 0: set CPU thread count to 10
# 2023-03-30T12:56:29-0600 [INFO] [cli] Prometheus metrics for HTTP BentoServer from "pretrained_classification_service:latest" can be accessed at http://localhost:3000/metrics.
# 2023-03-30T12:56:30-0600 [INFO] [cli] Starting production HTTP BentoServer from "pretrained_classification_service:latest" listening on http://0.0.0.0:3000 (Press CTRL+C to quit)
# Some weights of the model checkpoint at GroNLP/hateBERT were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at GroNLP/hateBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ^C

# %% [markdown]
# ## Deploy a fined-tuned Models
# Fine-tuning pretrained models is a powerful practice that allows users to save computation cost and adapt state-of-the-art models to their domain specific dataset. Transformers offers a variety of libraries for fine-tuning pretrained models.

# %%
from datasets import load_dataset
import evaluate
import numpy as np

from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    PreTrainedModel,
    Trainer, 
    TrainingArguments
)

datasets = load_dataset("imdb")
tokenizer = AutoTokenizer.from_pretrained("GroNLP/hateBERT")

def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)

tokenized_datasets = datasets.map(tokenize_function, batched=True)

label_list = tokenized_datasets["train"].unique("label")

# Load pre-trained model from huggingface hub

model = AutoModelForSequenceClassification.from_pretrained(
    "GroNLP/hateBERT", num_labels=len(label_list)
)

# create training arguments
training_args = TrainingArguments(
    output_dir="test_trainer", 
    evaluation_strategy="epoch",
    num_train_epochs=1,
    per_device_train_batch_size=16,

)

# define train set and eval set
train_set = tokenized_datasets["train"].shuffle(seed=42).select(range(1000))
validation_set = tokenized_datasets["test"].shuffle(seed=42).select(range(1000))

metric = evaluate.load("accuracy")
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)
trainer = Trainer(
model=model,
args=training_args,
train_dataset=train_set,
eval_dataset=validation_set,
compute_metrics=compute_metrics,
)
trainer.train()
# Out:
# Found cached dataset imdb (/Users/li/.cache/huggingface/datasets/imdb/plain_text/1.0.0/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Loading cached processed dataset at /Users/li/.cache/huggingface/datasets/imdb/plain_text/1.0.0/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0/cache-52fa01bddfaeae7a.arrow
# Loading cached processed dataset at /Users/li/.cache/huggingface/datasets/imdb/plain_text/1.0.0/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0/cache-b997016ac30a8840.arrow
# Loading cached processed dataset at /Users/li/.cache/huggingface/datasets/imdb/plain_text/1.0.0/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0/cache-508808c0d29b9b55.arrow
# Some weights of the model checkpoint at GroNLP/hateBERT were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.decoder.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at GroNLP/hateBERT and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.scriptrun = azureml.core.script_run:ScriptRun._from_run_dto with exception (packaging 23.0 (/Users/li/conda/miniconda3/envs/zenml/lib/python3.8/site-packages), Requirement.parse('packaging<22.0,>=20.0')).
# Loading cached shuffled indices for dataset at /Users/li/.cache/huggingface/datasets/imdb/plain_text/1.0.0/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0/cache-6c0f16b04e51a327.arrow
# Loading cached shuffled indices for dataset at /Users/li/.cache/huggingface/datasets/imdb/plain_text/1.0.0/d613c88cf8fa3bab83b4ded3713f1f74830d1100e171db75bbddb80b3345c9c0/cache-db51590e739839cf.arrow
# /Users/li/conda/miniconda3/envs/zenml/lib/python3.8/site-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/63 [00:00<?, ?it/s]
#   0%|          | 0/125 [00:00<?, ?it/s]
# {'eval_loss': 0.29997846484184265, 'eval_accuracy': 0.887, 'eval_runtime': 169.6525, 'eval_samples_per_second': 5.894, 'eval_steps_per_second': 0.737, 'epoch': 1.0}
# {'train_runtime': 804.5503, 'train_samples_per_second': 1.243, 'train_steps_per_second': 0.078, 'train_loss': 0.46503030686151414, 'epoch': 1.0}
# TrainOutput(global_step=63, training_loss=0.46503030686151414, metrics={'train_runtime': 804.5503, 'train_samples_per_second': 1.243, 'train_steps_per_second': 0.078, 'train_loss': 0.46503030686151414, 'epoch': 1.0})

# %% [markdown]
# ### save the fine-tuned model
# Once the model is fine-tuned, create a Transformers Pipeline with the model and save to the BentoML model store. By design, only Pipelines can be saved with the BentoML Transformers framework APIs. Models, tokenizers, feature extractors, and processors, need to be a part of the pipeline first before they can be saved. Transformers pipelines are callable objects therefore the signatures of the model are saved as __call__ by default.

# %%
from transformers import pipeline

classifier = pipeline('text-classification', model=model, tokenizer=tokenizer)

bentoml.transformers.save_model(name="text-classifier", pipeline=classifier)
# Out:
# No versions of Flax or Jax found on the current machine. In order to use Flax with transformers 4.x and above, refer to https://github.com/google/flax#quick-install
# Model(tag="text-classifier:v7onwdgorscej6wa", path="/Users/li/bentoml/models/text-classifier/v7onwdgorscej6wa/")

# %% [markdown]
# Redefine service

# %%
# %%writefile service.py
import bentoml

from bentoml.io import Text, JSON

runner = bentoml.transformers.get("text-classifier:latest").to_runner()

svc = bentoml.Service("text-classifier_service", runners=[runner])

@svc.api(input=Text(), output=JSON())
async def predict(input_series: str) -> list:
    return await runner.async_run(input_series)
# Out:
# Overwriting service.py

# %% [markdown]
# Test the server

# %%
# !bentoml serve service:svc --reload
# Out:
# 2023-03-30T13:15:22-0600 [INFO] [cli] Prometheus metrics for HTTP BentoServer from "service:svc" can be accessed at http://localhost:3000/metrics.
# 2023-03-30T13:15:22-0600 [INFO] [cli] Starting development HTTP BentoServer from "service:svc" listening on http://0.0.0.0:3000 (Press CTRL+C to quit)
# 2023-03-30 13:15:23 circus[71462] [INFO] Loading the plugin...
# 2023-03-30 13:15:23 circus[71462] [INFO] Endpoint: 'tcp://127.0.0.1:59318'
# 2023-03-30 13:15:23 circus[71462] [INFO] Pub/sub: 'tcp://127.0.0.1:59319'
# 2023-03-30T13:15:23-0600 [INFO] [observer] Watching directories: ['/Users/li/OMSA/FullStackDL/BentoML/huggingface_deployment', '/Users/li/bentoml/models']
# 2023-03-30T13:15:23-0600 [WARNING] [dev_api_server:text-classifier_service] No versions of Flax or Jax found on the current machine. In order to use Flax with transformers 4.x and above, refer to https://github.com/google/flax#quick-install
# 2023-03-30T13:16:23-0600 [INFO] [dev_api_server:text-classifier_service] 127.0.0.1:59383 (scheme=http,method=GET,path=/,type=,length=) (status=200,type=text/html; charset=utf-8,length=2859) 0.347ms (trace=2880d889a82fc6fc3abf7c50ccb37489,span=10a054df0cd0cd3a,sampled=0)
# 2023-03-30T13:16:23-0600 [INFO] [dev_api_server:text-classifier_service] 127.0.0.1:59383 (scheme=http,method=GET,path=/static_content/swagger-ui.css,type=,length=) (status=200,type=text/css; charset=utf-8,length=143980) 30.808ms (trace=bc7bdd47977fdc32e7355fc8cdc091a7,span=b6690988f58ae2fe,sampled=0)
# 2023-03-30T13:16:23-0600 [INFO] [dev_api_server:text-classifier_service] 127.0.0.1:59386 (scheme=http,method=GET,path=/static_content/swagger-ui-standalone-preset.js,type=,length=) (status=200,type=application/javascript,length=339540) 41.311ms (trace=1045ce092be4e297e4db8030de23286e,span=94c32dcb2be4223d,sampled=0)
# 2023-03-30T13:16:23-0600 [INFO] [dev_api_server:text-classifier_service] 127.0.0.1:59384 (scheme=http,method=GET,path=/static_content/swagger-ui-bundle.js,type=,length=) (status=200,type=application/javascript,length=1096221) 73.443ms (trace=f9f4d6f934800a19182a95cecb808a58,span=78bc396ab17a52be,sampled=0)
# 2023-03-30T13:16:24-0600 [INFO] [dev_api_server:text-classifier_service] 127.0.0.1:59384 (scheme=http,method=GET,path=/docs.json,type=,length=) (status=200,type=application/json,length=4557) 6.376ms (trace=a5063eac1ed6c8358287126d4ac62c77,span=6922cb2fb9c30e76,sampled=0)
# 2023-03-30T13:16:41-0600 [INFO] [dev_api_server:text-classifier_service] 127.0.0.1:59400 (scheme=http,method=POST,path=/predict,type=text/plain,length=9) (status=200,type=application/json,length=48) 62.857ms (trace=32db3c03951ad8d616ea4d4a280d2a99,span=49e81d7ad2ea8e63,sampled=0)
# ^C

# %% [markdown]
# Build bento

# %%
# !bentoml build
# Out:
# Building BentoML service "text-classifier_service:w3gbwkgpf6xep6wa" from build context "/Users/li/OMSA/FullStackDL/BentoML/huggingface_deployment".
# Packing model "text-classifier:v7onwdgorscej6wa"
# Locking PyPI package versions.
# /Users/li/conda/miniconda3/envs/zenml/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
#
# ██████╗░███████╗███╗░░██╗████████╗░█████╗░███╗░░░███╗██╗░░░░░
# ██╔══██╗██╔════╝████╗░██║╚══██╔══╝██╔══██╗████╗░████║██║░░░░░
# ██████╦╝█████╗░░██╔██╗██║░░░██║░░░██║░░██║██╔████╔██║██║░░░░░
# ██╔══██╗██╔══╝░░██║╚████║░░░██║░░░██║░░██║██║╚██╔╝██║██║░░░░░
# ██████╦╝███████╗██║░╚███║░░░██║░░░╚█████╔╝██║░╚═╝░██║███████╗
# ╚═════╝░╚══════╝╚═╝░░╚══╝░░░╚═╝░░░░╚════╝░╚═╝░░░░░╚═╝╚══════╝
#
# Successfully built Bento(tag="text-classifier_service:w3gbwkgpf6xep6wa").
#
# Possible next steps:
#
#  * Containerize your Bento with `bentoml containerize`:
#     $ bentoml containerize text-classifier_service:w3gbwkgpf6xep6wa
#
#  * Push to BentoCloud with `bentoml push`:
#     $ bentoml push text-classifier_service:w3gbwkgpf6xep6wa

# %% [markdown]
# ## Deploying Bentos in Sagemaker
# Prerequisites:
# - Terraform - Terraform is a tool for building, configuring, and managing infrastructure.
# - AWS CLI - installed and configured with an AWS account with permission to Sagemaker, Lambda and ECR configure AWS CLI and login docker

# %% [raw]
# In your terminal, run the following commands:
# aws configure
# aws ecr get-login-password --region us-east-2 | docker login --username AWS --password-stdin account.dkr.ecr.us-east-1.amazonaws.com
# #initiate bentoctl
# pip install bentoctl #if you haven't install it
# bentoctl operator install aws-sagemaker #if you haven't install it
# bentoctl init
# This will run the bentoctl generate command for you and will
# generate the main.tf terraform file,
# which specifies the resources to be created
# and the bentoctl.tfvars file which contains the values
# for the variables used in the main.tf file.

# %% [markdown]
# Build and push AWS sagemaker compatible docker image to the AWS ECR repository.

# %%
# !bentoctl build -b text-classifier_service:latest -f deployment_config.yaml
# Out:
# /Users/li/conda/miniconda3/envs/zenml/bin/bentoctl:5: DeprecationWarning: bentoml._internal.utils.buildx is deprecated. Make sure to use 'bentoml.container.build' and 'bentoml.container.health' instead.
#   from bentoctl.cli import bentoctl
# Usage of buildx:
#       --builder string
# Multiple '--platform' arguments were found. Make sure to also use '--push' to push images to a repository or generated images will not be saved. See https://docs.docker.com/engine/reference/commandline/buildx_build/#load.
# [+] Building 0.0s (0/0)
# [+] Building 0.0s (1/1)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
# [+] Building 0.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.1s
# [+] Building 0.3s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.2s
# [+] Building 0.4s (3/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
# [+] Building 0.5s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 2.87MB                                        0.1s
# [+] Building 0.6s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          0.2s
#  => => transferring context: 6.44MB                                        0.2s
# [+] Building 0.7s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          0.3s
#  => => transferring context: 9.91MB                                        0.3s
# [+] Building 0.9s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          0.5s
#  => => transferring context: 12.54MB                                       0.5s
# [+] Building 1.0s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          0.6s
#  => => transferring context: 16.01MB                                       0.6s
# [+] Building 1.2s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          0.7s
#  => => transferring context: 22.43MB                                       0.7s
# [+] Building 1.3s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          0.9s
#  => => transferring context: 25.71MB                                       0.9s
# [+] Building 1.5s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          1.0s
#  => => transferring context: 29.22MB                                       1.0s
# [+] Building 1.6s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          1.1s
#  => => transferring context: 36.04MB                                       1.1s
# [+] Building 1.7s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          1.2s
#  => => transferring context: 39.18MB                                       1.2s
# [+] Building 1.8s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          1.4s
#  => => transferring context: 42.43MB                                       1.4s
# [+] Building 2.0s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          1.5s
#  => => transferring context: 45.38MB                                       1.5s
# [+] Building 2.1s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          1.6s
#  => => transferring context: 51.80MB                                       1.6s
# [+] Building 2.2s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          1.7s
#  => => transferring context: 54.98MB                                       1.7s
# [+] Building 2.3s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          1.8s
#  => => transferring context: 57.83MB                                       1.8s
# [+] Building 2.4s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          1.9s
#  => => transferring context: 61.11MB                                       1.9s
# [+] Building 2.5s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          2.1s
#  => => transferring context: 64.85MB                                       2.1s
# [+] Building 2.7s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          2.2s
#  => => transferring context: 68.02MB                                       2.2s
# [+] Building 2.8s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          2.3s
#  => => transferring context: 75.24MB                                       2.3s
# [+] Building 2.9s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          2.4s
#  => => transferring context: 78.68MB                                       2.4s
# [+] Building 3.0s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          2.6s
#  => => transferring context: 82.41MB                                       2.6s
# [+] Building 3.2s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          2.7s
#  => => transferring context: 85.99MB                                       2.7s
# [+] Building 3.3s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          2.8s
#  => => transferring context: 92.84MB                                       2.8s
# [+] Building 3.4s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          2.9s
#  => => transferring context: 96.08MB                                       2.9s
# [+] Building 3.5s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          3.0s
#  => => transferring context: 99.65MB                                       3.0s
# [+] Building 3.6s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          3.1s
#  => => transferring context: 103.69MB                                      3.1s
# [+] Building 3.7s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          3.2s
#  => => transferring context: 107.45MB                                      3.2s
# [+] Building 3.8s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          3.3s
#  => => transferring context: 110.99MB                                      3.3s
# [+] Building 3.9s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          3.4s
#  => => transferring context: 114.08MB                                      3.4s
# [+] Building 4.0s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          3.5s
#  => => transferring context: 117.71MB                                      3.5s
# [+] Building 4.1s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          3.6s
#  => => transferring context: 121.52MB                                      3.6s
# [+] Building 4.2s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          3.7s
#  => => transferring context: 124.24MB                                      3.7s
# [+] Building 4.3s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          3.8s
#  => => transferring context: 127.61MB                                      3.8s
# [+] Building 4.4s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          3.9s
#  => => transferring context: 131.18MB                                      3.9s
# [+] Building 4.5s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          4.0s
#  => => transferring context: 134.89MB                                      4.0s
# [+] Building 4.6s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          4.1s
#  => => transferring context: 138.43MB                                      4.1s
# [+] Building 4.7s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          4.2s
#  => => transferring context: 141.90MB                                      4.2s
# [+] Building 4.8s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          4.3s
#  => => transferring context: 145.57MB                                      4.3s
# [+] Building 4.9s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          4.4s
#  => => transferring context: 149.37MB                                      4.4s
# [+] Building 5.0s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          4.5s
#  => => transferring context: 153.18MB                                      4.5s
# [+] Building 5.1s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          4.6s
#  => => transferring context: 156.65MB                                      4.6s
# [+] Building 5.2s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          4.7s
#  => => transferring context: 160.03MB                                      4.7s
# [+] Building 5.3s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          4.9s
#  => => transferring context: 163.14MB                                      4.9s
# [+] Building 5.5s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          5.0s
#  => => transferring context: 165.89MB                                      5.0s
# [+] Building 5.6s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          5.1s
#  => => transferring context: 172.68MB                                      5.1s
# [+] Building 5.7s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          5.3s
#  => => transferring context: 175.04MB                                      5.3s
# [+] Building 5.9s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          5.4s
#  => => transferring context: 178.45MB                                      5.4s
# [+] Building 6.0s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          5.5s
#  => => transferring context: 185.26MB                                      5.5s
# [+] Building 6.1s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          5.7s
#  => => transferring context: 188.90MB                                      5.6s
# [+] Building 6.2s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          5.8s
#  => => transferring context: 192.15MB                                      5.8s
# [+] Building 6.3s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          5.9s
#  => => transferring context: 195.79MB                                      5.9s
# [+] Building 6.4s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          6.0s
#  => => transferring context: 199.49MB                                      6.0s
# [+] Building 6.5s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          6.1s
#  => => transferring context: 203.36MB                                      6.1s
# [+] Building 6.6s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          6.2s
#  => => transferring context: 206.67MB                                      6.2s
# [+] Building 6.8s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          6.4s
#  => => transferring context: 210.50MB                                      6.4s
# [+] Building 6.9s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          6.5s
#  => => transferring context: 217.65MB                                      6.5s
# [+] Building 7.0s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          6.6s
#  => => transferring context: 221.02MB                                      6.6s
# [+] Building 7.1s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          6.7s
#  => => transferring context: 224.53MB                                      6.7s
# [+] Building 7.2s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          6.8s
#  => => transferring context: 228.17MB                                      6.8s
# [+] Building 7.3s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          6.9s
#  => => transferring context: 231.54MB                                      6.9s
# [+] Building 7.4s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.4s
#  => [base-container 1/9] FROM docker.io/library/python:3.8-slim@sha256:12  0.0s
#  => [internal] load build context                                          7.0s
#  => => transferring context: 234.95MB                                      7.0s
# [+] Building 7.6s (4/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.64kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
# e468d78ea69e: Pushed
# 219c6c2423f1: Pushed
# f9a132490cc3: Pushed
# 4c79cd85dee8: Pushed
# 9ef45d5dc37f: Pushed
# 5f70bf18a086: Pushed
# 83813a2e9aff: Pushed
# 17a007a32792: Pushed
# 3b08a5a46191: Pushed
# 222a0d4f2db1: Pushed
# 48df0d7cfecb: Pushed
# 529f4a059361: Pushed
# e468d78ea69e: Pushed
# 219c6c2423f1: Pushed
# f9a132490cc3: Pushed
# 4c79cd85dee8: Pushed
# 9ef45d5dc37f: Pushed
# 5f70bf18a086: Pushed
# 83813a2e9aff: Pushed
# 17a007a32792: Pushed
# 3b08a5a46191: Pushed
# 222a0d4f2db1: Pushed
# 48df0d7cfecb: Pushed
# 529f4a059361: Pushed
# e468d78ea69e: Pushed
# 219c6c2423f1: Pushed
# w3gbwkgpf6xep6wa: digest:
# sha256:a9ae8fb095c3ed89f00f461c6fbf6dd7932bb97bdde8435a603ec435d128f209 size:
# 3045
# f9a132490cc3: Pushed
# 4c79cd85dee8: Pushed
# 9ef45d5dc37f: Pushed
# 5f70bf18a086: Pushed
# 83813a2e9aff: Pushed
# 17a007a32792: Pushed
# 3b08a5a46191: Pushed
# 222a0d4f2db1: Pushed
# 48df0d7cfecb: Pushed
# 529f4a059361: Pushed
# e468d78ea69e: Pushed
# 219c6c2423f1: Pushed
# f9a132490cc3: Pushed
# 4c79cd85dee8: Pushed
# 9ef45d5dc37f: Pushed
# 5f70bf18a086: Pushed
# 83813a2e9aff: Pushed
# 17a007a32792: Pushed
# 3b08a5a46191: Pushed
# 222a0d4f2db1: Pushed
# 48df0d7cfecb: Pushed
# 529f4a059361: Pushed
# e468d78ea69e: Pushed
# 219c6c2423f1: Pushed
# 3af14c9a24c9: Pushed
# 🚀 Image pushed!
# ✨ generated template files.
#   - ./bentoctl.tfvars
#
# bentoctl has built and pushed the bento and generated the terraform files 🎉
#
# Now follow the steps below to use terraform to carry out the deployment
# 1. Initialise the terraform working directory.
# $ terraform init
#
# 2. Run terraform plan to see the changes that will take place
# $ terraform plan -var-file bentoctl.tfvars
#
# 3. Apply the changes to create the actual infrastructure
# $ terraform apply -var-file bentoctl.tfvars
#
# To cleanup all the resources and delete the repositories created run
# $ bentoctl destroy
#
# ---
# There is also an experimental command that you can use.
# To create the resources specifed run this after the build command.
# $ bentoctl apply
#
# To cleanup all the resources created and delete the registry run
# $ bentoctl destroy

# %% [markdown]
# ## Apply Deployment with Terraform
# Initialize terraform project. This installs the AWS provider and sets up the terraform folders.

# %%
#!terraform init
#Apply terraform project to create Sagemaker deployment
# !terraform apply -var-file=bentoctl.tfvars -auto-approve
# Out:
# aws_apigatewayv2_api.lambda: Refreshing state... [id=271qbbgdqc]
# data.aws_ecr_repository.service: Reading...
# aws_cloudwatch_log_group.api_gw: Refreshing state... [id=/aws/api_gw/finetuned-classifier-gw]
# aws_apigatewayv2_stage.lambda: Refreshing state... [id=$default]
# data.aws_ecr_repository.service: Read complete after 2s [id=finetuned_classifier]
# data.aws_ecr_image.service_image: Reading...
# data.aws_ecr_image.service_image: Read complete after 1s [id=sha256:a9ae8fb095c3ed89f00f461c6fbf6dd7932bb97bdde8435a603ec435d128f209]
# aws_sagemaker_model.sagemaker_model: Refreshing state... [id=finetuned-classifier-model-w3gbwkgpf6xep6wa]
# aws_sagemaker_endpoint_configuration.endpoint_config: Refreshing state... [id=finetuned-classifier-endpoint-config-w3gbwkgpf6xep6wa]
# aws_sagemaker_endpoint.sagemaker_endpoint: Refreshing state... [id=finetuned-classifier-endpoint]
# data.archive_file.lambda_inline_zip: Reading...
# data.archive_file.lambda_inline_zip: Read complete after 0s [id=97dbf248ca0560c36e28b2a48abfb8136696bdd0]
# aws_lambda_function.fn: Refreshing state... [id=finetuned-classifier-function]
# aws_cloudwatch_log_group.lg: Refreshing state... [id=/aws/lambda/finetuned-classifier-function]
# aws_lambda_permission.api_gw: Refreshing state... [id=AllowExecutionFromAPIGateway]
# aws_apigatewayv2_integration.lambda: Refreshing state... [id=cfp7fj4]
# aws_apigatewayv2_route.endpoints: Refreshing state... [id=8m9x579]
#
# Apply complete! Resources: 0 added, 0 changed, 0 destroyed.
#
# Outputs:
#
# ecr_image_tag = "374806654920.dkr.ecr.us-east-2.amazonaws.com/finetuned_classifier:w3gbwkgpf6xep6wa"
# endpoint = "https://271qbbgdqc.execute-api.us-east-2.amazonaws.com/"

# %% [markdown]
# ## invoke the endpoint

# %%
#374806654920.dkr.ecr.us-east-2.amazonaws.com/pretrained_classification:2qgvurwfjojwv6wa
#https://runtime.sagemaker.us-east-2.amazonaws.com/endpoints/quickstart-endpoint/invocations
import boto3

# Create a low-level client representing Amazon SageMaker Runtime
sagemaker_runtime = boto3.client("sagemaker-runtime", region_name="us-east-2")

# The name of the endpoint. The name must be unique within an AWS Region in your AWS account. 
endpoint_name='finetuned-classifier-endpoint'

# After you deploy a model into production using SageMaker hosting 
# services, your client applications use this API to get inferences 
# from the model hosted at the specified endpoint.
response = sagemaker_runtime.invoke_endpoint(
                            EndpointName=endpoint_name, 
                            Body=bytes('{"body": "This is great!"}', 'utf-8') # Replace with your own data.
                            )

# Optional - Print the response body and decode it so it is human read-able.
print(response['Body'].read().decode('utf-8'))
# Out:
# [{"label":"LABEL_0","score":0.6155382990837097}]

# %% [markdown]
# ## test API

# %% [raw]
# $ URL=$(terraform output -json | jq -r .endpoint.value)predict
# $ curl $URL -d '{"body": "This is great!"}'
# [{"label":"LABEL_0","score":0.6155382990837097}]

# %% [markdown]
# ## Delete deployment Use the bentoctl destroy command to remove the registry and the deployment

# %%
# !bentoctl destroy -f deployment_config.yaml
# Out:
# /Users/li/conda/miniconda3/envs/zenml/bin/bentoctl:5: DeprecationWarning: bentoml._internal.utils.buildx is deprecated. Make sure to use 'bentoml.container.build' and 'bentoml.container.health' instead.
#   from bentoctl.cli import bentoctl
# data.aws_ecr_repository.service: Reading...
# aws_apigatewayv2_api.lambda: Refreshing state... [id=271qbbgdqc]
# data.aws_ecr_repository.service: Read complete after 1s [id=finetuned_classifier]
# data.aws_ecr_image.service_image: Reading...
# data.aws_ecr_image.service_image: Read complete after 0s [id=sha256:a9ae8fb095c3ed89f00f461c6fbf6dd7932bb97bdde8435a603ec435d128f209]
# aws_sagemaker_model.sagemaker_model: Refreshing state... [id=finetuned-classifier-model-w3gbwkgpf6xep6wa]
# aws_cloudwatch_log_group.api_gw: Refreshing state... [id=/aws/api_gw/finetuned-classifier-gw]
# aws_sagemaker_endpoint_configuration.endpoint_config: Refreshing state... [id=finetuned-classifier-endpoint-config-w3gbwkgpf6xep6wa]
# aws_sagemaker_endpoint.sagemaker_endpoint: Refreshing state... [id=finetuned-classifier-endpoint]
# aws_apigatewayv2_stage.lambda: Refreshing state... [id=$default]
# data.archive_file.lambda_inline_zip: Reading...
# data.archive_file.lambda_inline_zip: Read complete after 0s [id=97dbf248ca0560c36e28b2a48abfb8136696bdd0]
# aws_lambda_function.fn: Refreshing state... [id=finetuned-classifier-function]
# aws_apigatewayv2_integration.lambda: Refreshing state... [id=cfp7fj4]
# aws_cloudwatch_log_group.lg: Refreshing state... [id=/aws/lambda/finetuned-classifier-function]
# aws_lambda_permission.api_gw: Refreshing state... [id=AllowExecutionFromAPIGateway]
# aws_apigatewayv2_route.endpoints: Refreshing state... [id=8m9x579]
#
# Terraform used the selected providers to generate the following execution plan.
# Resource actions are indicated with the following symbols:
#   - destroy
#
# Terraform will perform the following actions:
#
#   # aws_apigatewayv2_api.lambda will be destroyed
#   - resource "aws_apigatewayv2_api" "lambda" {
#       - api_endpoint                 = "https://271qbbgdqc.execute-api.us-east-2.amazonaws.com" -> null
#       - api_key_selection_expression = "$request.header.x-api-key" -> null
#       - arn                          = "arn:aws:apigateway:us-east-2::/apis/271qbbgdqc" -> null
#       - disable_execute_api_endpoint = false -> null
#       - execution_arn                = "arn:aws:execute-api:us-east-2:374806654920:271qbbgdqc" -> null
#       - id                           = "271qbbgdqc" -> null
#       - name                         = "finetuned-classifier-gw" -> null
#       - protocol_type                = "HTTP" -> null
#       - route_selection_expression   = "$request.method $request.path" -> null
#       - tags                         = {} -> null
#       - tags_all                     = {} -> null
#     }
#
#   # aws_apigatewayv2_integration.lambda will be destroyed
#   - resource "aws_apigatewayv2_integration" "lambda" {
#       - api_id                 = "271qbbgdqc" -> null
#       - connection_type        = "INTERNET" -> null
#       - id                     = "cfp7fj4" -> null
#       - integration_method     = "POST" -> null
#       - integration_type       = "AWS_PROXY" -> null
#       - integration_uri        = "arn:aws:apigateway:us-east-2:lambda:path/2015-03-31/functions/arn:aws:lambda:us-east-2:374806654920:function:finetuned-classifier-function/invocations" -> null
#       - payload_format_version = "1.0" -> null
#       - request_parameters     = {} -> null
#       - request_templates      = {} -> null
#       - timeout_milliseconds   = 30000 -> null
#     }
#
#   # aws_apigatewayv2_route.endpoints will be destroyed
#   - resource "aws_apigatewayv2_route" "endpoints" {
#       - api_id               = "271qbbgdqc" -> null
#       - api_key_required     = false -> null
#       - authorization_scopes = [] -> null
#       - authorization_type   = "NONE" -> null
#       - id                   = "8m9x579" -> null
#       - request_models       = {} -> null
#       - route_key            = "POST /{proxy+}" -> null
#       - target               = "integrations/cfp7fj4" -> null
#     }
#
#   # aws_apigatewayv2_stage.lambda will be destroyed
#   - resource "aws_apigatewayv2_stage" "lambda" {
#       - api_id          = "271qbbgdqc" -> null
#       - arn             = "arn:aws:apigateway:us-east-2::/apis/271qbbgdqc/stages/$default" -> null
#       - auto_deploy     = true -> null
#       - deployment_id   = "mhqqf5" -> null
#       - execution_arn   = "arn:aws:execute-api:us-east-2:374806654920:271qbbgdqc/$default" -> null
#       - id              = "$default" -> null
#       - invoke_url      = "https://271qbbgdqc.execute-api.us-east-2.amazonaws.com/" -> null
#       - name            = "$default" -> null
#       - stage_variables = {} -> null
#       - tags            = {} -> null
#       - tags_all        = {} -> null
#
#       - access_log_settings {
#           - destination_arn = "arn:aws:logs:us-east-2:374806654920:log-group:/aws/api_gw/finetuned-classifier-gw" -> null
#           - format          = jsonencode(
#                 {
#                   - httpMethod              = "$context.httpMethod"
#                   - integrationErrorMessage = "$context.integrationErrorMessage"
#                   - protocol                = "$context.protocol"
#                   - requestId               = "$context.requestId"
#                   - requestTime             = "$context.requestTime"
#                   - resourcePath            = "$context.resourcePath"
#                   - responseLength          = "$context.responseLength"
#                   - routeKey                = "$context.routeKey"
#                   - sourceIp                = "$context.identity.sourceIp"
#                   - status                  = "$context.status"
#                 }
#             ) -> null
#         }
#
#       - default_route_settings {
#           - data_trace_enabled       = false -> null
#           - detailed_metrics_enabled = false -> null
#           - throttling_burst_limit   = 0 -> null
#           - throttling_rate_limit    = 0 -> null
#         }
#     }
#
#   # aws_cloudwatch_log_group.api_gw will be destroyed
#   - resource "aws_cloudwatch_log_group" "api_gw" {
#       - arn               = "arn:aws:logs:us-east-2:374806654920:log-group:/aws/api_gw/finetuned-classifier-gw" -> null
#       - id                = "/aws/api_gw/finetuned-classifier-gw" -> null
#       - name              = "/aws/api_gw/finetuned-classifier-gw" -> null
#       - retention_in_days = 30 -> null
#       - tags              = {} -> null
#       - tags_all          = {} -> null
#     }
#
#   # aws_cloudwatch_log_group.lg will be destroyed
#   - resource "aws_cloudwatch_log_group" "lg" {
#       - arn               = "arn:aws:logs:us-east-2:374806654920:log-group:/aws/lambda/finetuned-classifier-function" -> null
#       - id                = "/aws/lambda/finetuned-classifier-function" -> null
#       - name              = "/aws/lambda/finetuned-classifier-function" -> null
#       - retention_in_days = 30 -> null
#       - tags              = {} -> null
#       - tags_all          = {} -> null
#     }
#
#   # aws_lambda_function.fn will be destroyed
#   - resource "aws_lambda_function" "fn" {
#       - architectures                  = [
#           - "x86_64",
#         ] -> null
#       - arn                            = "arn:aws:lambda:us-east-2:374806654920:function:finetuned-classifier-function" -> null
#       - description                    = "A proxy service to invoke sagemaker endpoint." -> null
#       - filename                       = "/tmp/lambda_zip_inline.zip" -> null
#       - function_name                  = "finetuned-classifier-function" -> null
#       - handler                        = "index.lambda_handler" -> null
#       - id                             = "finetuned-classifier-function" -> null
#       - invoke_arn                     = "arn:aws:apigateway:us-east-2:lambda:path/2015-03-31/functions/arn:aws:lambda:us-east-2:374806654920:function:finetuned-classifier-function/invocations" -> null
#       - last_modified                  = "2023-03-30T20:56:21.200+0000" -> null
#       - layers                         = [] -> null
#       - memory_size                    = 128 -> null
#       - package_type                   = "Zip" -> null
#       - publish                        = false -> null
#       - qualified_arn                  = "arn:aws:lambda:us-east-2:374806654920:function:finetuned-classifier-function:$LATEST" -> null
#       - reserved_concurrent_executions = -1 -> null
#       - role                           = "arn:aws:iam::374806654920:role/AnalyticsLambdaExecRole" -> null
#       - runtime                        = "python3.9" -> null
#       - source_code_hash               = "waJoye8TjcelOk0SyskSRBz9P2+3VzaZprmzu+wm/bk=" -> null
#       - source_code_size               = 539 -> null
#       - tags                           = {} -> null
#       - tags_all                       = {} -> null
#       - timeout                        = 60 -> null
#       - version                        = "$LATEST" -> null
#
#       - tracing_config {
#           - mode = "PassThrough" -> null
#         }
#     }
#
#   # aws_lambda_permission.api_gw will be destroyed
#   - resource "aws_lambda_permission" "api_gw" {
#       - action        = "lambda:InvokeFunction" -> null
#       - function_name = "finetuned-classifier-function" -> null
#       - id            = "AllowExecutionFromAPIGateway" -> null
#       - principal     = "apigateway.amazonaws.com" -> null
#       - source_arn    = "arn:aws:execute-api:us-east-2:374806654920:271qbbgdqc/*/*" -> null
#       - statement_id  = "AllowExecutionFromAPIGateway" -> null
#     }
#
#   # aws_sagemaker_endpoint.sagemaker_endpoint will be destroyed
#   - resource "aws_sagemaker_endpoint" "sagemaker_endpoint" {
#       - arn                  = "arn:aws:sagemaker:us-east-2:374806654920:endpoint/finetuned-classifier-endpoint" -> null
#       - endpoint_config_name = "finetuned-classifier-endpoint-config-w3gbwkgpf6xep6wa" -> null
#       - id                   = "finetuned-classifier-endpoint" -> null
#       - name                 = "finetuned-classifier-endpoint" -> null
#       - tags                 = {} -> null
#       - tags_all             = {} -> null
#     }
#
#   # aws_sagemaker_endpoint_configuration.endpoint_config will be destroyed
#   - resource "aws_sagemaker_endpoint_configuration" "endpoint_config" {
#       - arn      = "arn:aws:sagemaker:us-east-2:374806654920:endpoint-config/finetuned-classifier-endpoint-config-w3gbwkgpf6xep6wa" -> null
#       - id       = "finetuned-classifier-endpoint-config-w3gbwkgpf6xep6wa" -> null
#       - name     = "finetuned-classifier-endpoint-config-w3gbwkgpf6xep6wa" -> null
#       - tags     = {} -> null
#       - tags_all = {} -> null
#
#       - production_variants {
#           - initial_instance_count = 1 -> null
#           - initial_variant_weight = 1 -> null
#           - instance_type          = "ml.t2.medium" -> null
#           - model_name             = "finetuned-classifier-model-w3gbwkgpf6xep6wa" -> null
#           - variant_name           = "default" -> null
#         }
#     }
#
#   # aws_sagemaker_model.sagemaker_model will be destroyed
#   - resource "aws_sagemaker_model" "sagemaker_model" {
#       - arn                      = "arn:aws:sagemaker:us-east-2:374806654920:model/finetuned-classifier-model-w3gbwkgpf6xep6wa" -> null
#       - enable_network_isolation = false -> null
#       - execution_role_arn       = "arn:aws:iam::374806654920:role/PinwheelAnalyticsSagemakerExecRole" -> null
#       - id                       = "finetuned-classifier-model-w3gbwkgpf6xep6wa" -> null
#       - name                     = "finetuned-classifier-model-w3gbwkgpf6xep6wa" -> null
#       - tags                     = {} -> null
#       - tags_all                 = {} -> null
#
#       - primary_container {
#           - environment = {} -> null
#           - image       = "374806654920.dkr.ecr.us-east-2.amazonaws.com/finetuned_classifier@sha256:a9ae8fb095c3ed89f00f461c6fbf6dd7932bb97bdde8435a603ec435d128f209" -> null
#           - mode        = "SingleModel" -> null
#         }
#     }
#
# Plan: 0 to add, 0 to change, 11 to destroy.
#
# Changes to Outputs:
#   - ecr_image_tag = "374806654920.dkr.ecr.us-east-2.amazonaws.com/finetuned_classifier:w3gbwkgpf6xep6wa" -> null
#   - endpoint      = "https://271qbbgdqc.execute-api.us-east-2.amazonaws.com/" -> null
# aws_apigatewayv2_stage.lambda: Destroying... [id=$default]
# aws_apigatewayv2_route.endpoints: Destroying... [id=8m9x579]
# aws_lambda_permission.api_gw: Destroying... [id=AllowExecutionFromAPIGateway]
# aws_cloudwatch_log_group.lg: Destroying... [id=/aws/lambda/finetuned-classifier-function]
# aws_cloudwatch_log_group.lg: Destruction complete after 0s
# aws_apigatewayv2_route.endpoints: Destruction complete after 1s
# aws_apigatewayv2_integration.lambda: Destroying... [id=cfp7fj4]
# aws_lambda_permission.api_gw: Destruction complete after 1s
# aws_apigatewayv2_stage.lambda: Destruction complete after 1s
# aws_cloudwatch_log_group.api_gw: Destroying... [id=/aws/api_gw/finetuned-classifier-gw]
# aws_apigatewayv2_integration.lambda: Destruction complete after 0s
# aws_lambda_function.fn: Destroying... [id=finetuned-classifier-function]
# aws_cloudwatch_log_group.api_gw: Destruction complete after 0s
# aws_apigatewayv2_api.lambda: Destroying... [id=271qbbgdqc]
# aws_lambda_function.fn: Destruction complete after 0s
# aws_sagemaker_endpoint.sagemaker_endpoint: Destroying... [id=finetuned-classifier-endpoint]
# aws_apigatewayv2_api.lambda: Destruction complete after 1s
# aws_sagemaker_endpoint.sagemaker_endpoint: Still destroying... [id=finetuned-classifier-endpoint, 10s elapsed]
# aws_sagemaker_endpoint.sagemaker_endpoint: Still destroying... [id=finetuned-classifier-endpoint, 20s elapsed]
# aws_sagemaker_endpoint.sagemaker_endpoint: Still destroying... [id=finetuned-classifier-endpoint, 30s elapsed]
# aws_sagemaker_endpoint.sagemaker_endpoint: Destruction complete after 32s
# aws_sagemaker_endpoint_configuration.endpoint_config: Destroying... [id=finetuned-classifier-endpoint-config-w3gbwkgpf6xep6wa]
# aws_sagemaker_endpoint_configuration.endpoint_config: Destruction complete after 0s
# aws_sagemaker_model.sagemaker_model: Destroying... [id=finetuned-classifier-model-w3gbwkgpf6xep6wa]
# aws_sagemaker_model.sagemaker_model: Destruction complete after 1s
#
# Apply complete! Resources: 0 added, 0 changed, 11 destroyed.
# Repository finetuned-classifier not found. Skipping registry cleanup
# Deleted the repository finetuned-classifier
